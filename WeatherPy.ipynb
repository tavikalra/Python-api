# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp =city_weather['main']['temp_min']
        city_humidity = city_weather['main']['humidity']
        city_clouds =city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country =city_weather['sys']['country']
        city_date = city_weather['dt']


        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | necochea
# Processing Record 2 of Set 1 | guane
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | olonkinbyen
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | magadan
# Processing Record 9 of Set 1 | labrador city
# Processing Record 10 of Set 1 | vila velha
# Processing Record 11 of Set 1 | inhambane
# Processing Record 12 of Set 1 | zaozersk
# Processing Record 13 of Set 1 | louth
# Processing Record 14 of Set 1 | saint-pierre
# Processing Record 15 of Set 1 | atafu village
# Processing Record 16 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 17 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | mandiana
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | chapaev
# Processing Record 22 of Set 1 | marsh harbour
# Processing Record 23 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 1 | papatowai
# Processing Record 25 of Set 1 | nar'yan-mar
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | waitangi
# Processing Record 28 of Set 1 | hede
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | stanley
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | puerto natales
# Processing Record 34 of Set 1 | grytviken
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | la passe
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | itoman
# Processing Record 39 of Set 1 | hotan
# Processing Record 40 of Set 1 | dimona
# Processing Record 41 of Set 1 | whitehorse
# Processing Record 42 of Set 1 | hawaiian paradise park
# Processing Record 43 of Set 1 | puno
# Processing Record 44 of Set 1 | villa gesell
# Processing Record 45 of Set 1 | acajutla
# Processing Record 46 of Set 1 | zouerate
# Processing Record 47 of Set 1 | flying fish cove
# Processing Record 48 of Set 1 | arkhangel'sk
# Processing Record 49 of Set 1 | kavaratti
# Processing Record 50 of Set 1 | rizhao
# Processing Record 0 of Set 2 | bentota
# Processing Record 1 of Set 2 | balqash
# Processing Record 2 of Set 2 | kawthoung
# City not found. Skipping...
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | altai
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | swakopmund
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | chonchi
# Processing Record 9 of Set 2 | tharangambadi
# Processing Record 10 of Set 2 | alotau
# Processing Record 11 of Set 2 | badger
# Processing Record 12 of Set 2 | wuwei
# Processing Record 13 of Set 2 | port mathurin
# Processing Record 14 of Set 2 | qaqortoq
# Processing Record 15 of Set 2 | ola
# Processing Record 16 of Set 2 | iskateley
# Processing Record 17 of Set 2 | the pas
# Processing Record 18 of Set 2 | adamstown
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | saipan
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | isafjordur
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | dalandzadgad
# Processing Record 27 of Set 2 | nushki
# Processing Record 28 of Set 2 | ba
# City not found. Skipping...
# Processing Record 29 of Set 2 | akureyri
# Processing Record 30 of Set 2 | puerto leguizamo
# Processing Record 31 of Set 2 | namdrik
# Processing Record 32 of Set 2 | invercargill
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | kapuskasing
# Processing Record 35 of Set 2 | conception bay south
# Processing Record 36 of Set 2 | swift current
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | eastham
# Processing Record 14 of Set 4 | minab
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | emerald
# Processing Record 17 of Set 4 | kasongo-lunda
# Processing Record 18 of Set 4 | east london
# Processing Record 19 of Set 4 | escanaba
# Processing Record 20 of Set 4 | merizo village
# Processing Record 21 of Set 4 | west island
# Processing Record 22 of Set 4 | vorgashor
# Processing Record 23 of Set 4 | port elizabeth
# Processing Record 24 of Set 4 | fort mcmurray
# Processing Record 25 of Set 4 | puerto baquerizo moreno
# Processing Record 26 of Set 4 | cidreira
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | puerto aysen
# Processing Record 29 of Set 4 | mersa matruh
# Processing Record 30 of Set 4 | camapua
# Processing Record 31 of Set 4 | happy valley-goose bay
# Processing Record 32 of Set 4 | queenstown
# Processing Record 33 of Set 4 | nova vicosa
# Processing Record 34 of Set 4 | la'ie
# Processing Record 35 of Set 4 | prince rupert
# Processing Record 36 of Set 4 | ponta delgada
# Processing Record 37 of Set 4 | prado
# Processing Record 38 of Set 4 | alofi
# Processing Record 39 of Set 4 | vernon
# Processing Record 40 of Set 4 | muhos
# Processing Record 41 of Set 4 | nyurba
# Processing Record 42 of Set 4 | mahanoro
# Processing Record 43 of Set 4 | nova sintra
# Processing Record 44 of Set 4 | vilyuchinsk
# Processing Record 45 of Set 4 | aleksandrov gay
# Processing Record 46 of Set 4 | changsha
# Processing Record 47 of Set 4 | honefoss
# Processing Record 48 of Set 4 | tanjung pandan
# Processing Record 49 of Set 4 | chegdomyn
# Processing Record 0 of Set 5 | hami
# Processing Record 1 of Set 5 | belo sur tsiribihina
# Processing Record 2 of Set 5 | soe
# Processing Record 3 of Set 5 | gelemso
# Processing Record 4 of Set 5 | taishan
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | fort myers shores
# Processing Record 7 of Set 5 | calvinia
# Processing Record 8 of Set 5 | madison
# Processing Record 9 of Set 5 | san felipe
# Processing Record 10 of Set 5 | kerikeri
# Processing Record 11 of Set 5 | mosjoen
# Processing Record 12 of Set 5 | aromashevo
# Processing Record 13 of Set 5 | faya-largeau
# Processing Record 14 of Set 5 | nuuk
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | garoowe
# Processing Record 17 of Set 5 | klyuchi
# Processing Record 18 of Set 5 | shimoda
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | newman
# Processing Record 21 of Set 5 | veraval
# Processing Record 22 of Set 5 | apostolove
# Processing Record 23 of Set 5 | maragogi
# Processing Record 24 of Set 5 | kampene
# Processing Record 25 of Set 5 | mahalapye
# Processing Record 26 of Set 5 | kingston
# Processing Record 27 of Set 5 | hastings
# Processing Record 28 of Set 5 | zaragoza
# Processing Record 29 of Set 5 | lagawe
# Processing Record 30 of Set 5 | zabol
# Processing Record 31 of Set 5 | mesquite
# Processing Record 32 of Set 5 | hermanus
# Processing Record 33 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 34 of Set 5 | hobyo
# Processing Record 35 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 36 of Set 5 | kailua-kona
# Processing Record 37 of Set 5 | guigue
# Processing Record 38 of Set 5 | freeport
# Processing Record 39 of Set 5 | aasiaat
# City not found. Skipping...
# Processing Record 40 of Set 5 | holualoa
# Processing Record 41 of Set 5 | tamanrasset
# Processing Record 42 of Set 5 | la sarre
# Processing Record 43 of Set 5 | enewetak
# Processing Record 44 of Set 5 | fredonia
# Processing Record 45 of Set 5 | leticia
# Processing Record 46 of Set 5 | medjez el bab
# Processing Record 47 of Set 5 | fale old settlement
# Processing Record 48 of Set 5 | mumbwa
# Processing Record 49 of Set 5 | praia
# Processing Record 0 of Set 6 | bovalino
# Processing Record 1 of Set 6 | al hawatah
# Processing Record 2 of Set 6 | ambon
# Processing Record 3 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 4 of Set 6 | jining
# Processing Record 5 of Set 6 | minas de marcona
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | nanao
# Processing Record 8 of Set 6 | vail
# Processing Record 9 of Set 6 | carterton
# Processing Record 10 of Set 6 | leava
# Processing Record 11 of Set 6 | gouyave
# Processing Record 12 of Set 6 | aboso
# Processing Record 13 of Set 6 | katsuura
# Processing Record 14 of Set 6 | san antonio de pale
# Processing Record 15 of Set 6 | lauro de freitas
# Processing Record 16 of Set 6 | ain defla
# Processing Record 17 of Set 6 | laikit, laikit ii (dimembe)
# Processing Record 18 of Set 6 | kirovsk
# Processing Record 19 of Set 6 | viedma
# Processing Record 20 of Set 6 | kirandul
# City not found. Skipping...
# Processing Record 21 of Set 6 | saint-joseph
# Processing Record 22 of Set 6 | remire-montjoly
# Processing Record 23 of Set 6 | lihue
# Processing Record 24 of Set 6 | naze
# Processing Record 25 of Set 6 | ha'il
# Processing Record 26 of Set 6 | maceio
# Processing Record 27 of Set 6 | muli
# Processing Record 28 of Set 6 | mariental
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | malango
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | choibalsan
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | sao joao da barra
# Processing Record 35 of Set 6 | el galpon
# Processing Record 36 of Set 6 | isangel
# Processing Record 37 of Set 6 | jamestown
# Processing Record 38 of Set 6 | pacific grove
# Processing Record 39 of Set 6 | kenai
# Processing Record 40 of Set 6 | malabar
# Processing Record 41 of Set 6 | komsomol'sk
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | suez
# Processing Record 44 of Set 6 | lata
# Processing Record 45 of Set 6 | yaren
# Processing Record 46 of Set 6 | fallon
# Processing Record 47 of Set 6 | mhangura
# Processing Record 48 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record
# Processing Record 22 of Set 8 | taulaga
# Processing Record 23 of Set 8 | fria
# Processing Record 24 of Set 8 | kichmengskiy gorodok
# Processing Record 25 of Set 8 | bubaque
# Processing Record 26 of Set 8 | menongue
# Processing Record 27 of Set 8 | villa angela
# Processing Record 28 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 29 of Set 8 | new plymouth
# Processing Record 30 of Set 8 | usogorsk
# Processing Record 31 of Set 8 | westport
# Processing Record 32 of Set 8 | mount isa
# Processing Record 33 of Set 8 | mount pearl
# Processing Record 34 of Set 8 | hacienda la calera
# Processing Record 35 of Set 8 | daura
# Processing Record 36 of Set 8 | sechura
# Processing Record 37 of Set 8 | balancan
# Processing Record 38 of Set 8 | arar
# Processing Record 39 of Set 8 | porto novo
# Processing Record 40 of Set 8 | sitka
# Processing Record 41 of Set 8 | nishinoomote
# Processing Record 42 of Set 8 | baise city
# Processing Record 43 of Set 8 | paracuru
# Processing Record 44 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 45 of Set 8 | luba
# Processing Record 46 of Set 8 | tyuratam
# Processing Record 47 of Set 8 | xinyuan
# Processing Record 48 of Set 8 | gobabis
# Processing Record 49 of Set 8 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 0 of Set 9 | el alto
# Processing Record 1 of Set 9 | arawa
# Processing Record 2 of Set 9 | kondagaon
# Processing Record 3 of Set 9 | kirishi
# Processing Record 4 of Set 9 | whangarei
# Processing Record 5 of Set 9 | santa elena
# Processing Record 6 of Set 9 | cherepanovo
# Processing Record 7 of Set 9 | awjilah
# Processing Record 8 of Set 9 | zapolyarnyy
# Processing Record 9 of Set 9 | loiza
# Processing Record 10 of Set 9 | lazaro cardenas
# Processing Record 11 of Set 9 | conselheiro pena
# Processing Record 12 of Set 9 | rayne
# Processing Record 13 of Set 9 | sisimiut
# Processing Record 14 of Set 9 | berdyansk
# Processing Record 15 of Set 9 | quezon
# Processing Record 16 of Set 9 | kloulklubed
# Processing Record 17 of Set 9 | isoka
# Processing Record 18 of Set 9 | waterville
# Processing Record 19 of Set 9 | buka
# Processing Record 20 of Set 9 | salinopolis
# Processing Record 21 of Set 9 | nishon tumani
# Processing Record 22 of Set 9 | salekhard
# Processing Record 23 of Set 9 | tra vinh
# Processing Record 24 of Set 9 | klaksvik
# Processing Record 25 of Set 9 | moussoro
# Processing Record 26 of Set 9 | preobrazheniye
# Processing Record 27 of Set 9 | paros
# Processing Record 28 of Set 9 | cill airne
# Processing Record 29 of Set 9 | howard springs
# Processing Record 30 of Set 9 | lodwar
# Processing Record 31 of Set 9 | valdivia
# Processing Record 32 of Set 9 | papao
# Processing Record 33 of Set 9 | hadibu
# Processing Record 34 of Set 9 | la ronge
# Processing Record 35 of Set 9 | tazacorte
# Processing Record 36 of Set 9 | plettenberg bay
# Processing Record 37 of Set 9 | mangrol
# Processing Record 38 of Set 9 | afaahiti
# Processing Record 39 of Set 9 | savanna-la-mar
# Processing Record 40 of Set 9 | hassi messaoud
# Processing Record 41 of Set 9 | okha
# Processing Record 42 of Set 9 | tandil
# Processing Record 43 of Set 9 | puerto madero
# Processing Record 44 of Set 9 | sinabang
# Processing Record 45 of Set 9 | ma'ili
# Processing Record 46 of Set 9 | kandahar
# Processing Record 47 of Set 9 | mugia
# Processing Record 48 of Set 9 | imbituba
# Processing Record 49 of Set 9 | arteche
# Processing Record 0 of Set 10 | lib
# Processing Record 1 of Set 10 | novodvinsk
# Processing Record 2 of Set 10 | makushino
# Processing Record 3 of Set 10 | palamos
# Processing Record 4 of Set 10 | ilhabela
# Processing Record 5 of Set 10 | askale
# Processing Record 6 of Set 10 | arenapolis
# Processing Record 7 of Set 10 | ta`u
# Processing Record 8 of Set 10 | rajpur
# Processing Record 9 of Set 10 | port-vila
# Processing Record 10 of Set 10 | ust'-kut
# Processing Record 11 of Set 10 | mazamari
# Processing Record 12 of Set 10 | ulladulla
# Processing Record 13 of Set 10 | tolanaro
# Processing Record 14 of Set 10 | aldinga beach
# Processing Record 15 of Set 10 | sovetskaya gavan'
# Processing Record 16 of Set 10 | krupki
# Processing Record 17 of Set 10 | bongor
# Processing Record 18 of Set 10 | ust-nera
# Processing Record 19 of Set 10 | atasu
# Processing Record 20 of Set 10 | grand falls-windsor
# Processing Record 21 of Set 10 | kamyanyets
# Processing Record 22 of Set 10 | bocaiuva
# Processing Record 23 of Set 10 | sambava
# Processing Record 24 of Set 10 | floro
# Processing Record 25 of Set 10 | skidel'
# Processing Record 26 of Set 10 | aripuana
# Processing Record 27 of Set 10 | mana
# Processing Record 28 of Set 10 | caazapa
# Processing Record 29 of Set 10 | torghay
# Processing Record 30 of Set 10 | general villegas
# Processing Record 31 of Set 10 | ugoofaaru
# Processing Record 32 of Set 10 | viqueque
# Processing Record 33 of Set 10 | pestovo
# Processing Record 34 of Set 10 | cooper's town
# Processing Record 35 of Set 10 | comodoro rivadavia
# Processing Record 36 of Set 10 | bondo
# Processing Record 37 of Set 10 | reuleuet
# Processing Record 38 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 39 of Set 10 | francisco sa
# Processing Record 40 of Set 10 | ust'-ilimsk
# Processing Record 41 of Set 10 | calaca
# Processing Record 42 of Set 10 | chaah
# Processing Record 43 of Set 10 | mvomero
# Processing Record 44 of Set 10 | itapirapua
# Processing Record 45 of Set 10 | angra do heroismo
# Processing Record 46 of Set 10 | villa regina
# Processing Record 47 of Set 10 | ivins
# Processing Record 48 of Set 10 | dareda
# Processing Record 49 of Set 10 | kaga bandoro
# Processing Record 0 of Set 11 | berdigestyakh
# Processing Record 1 of Set 11 | fort st. john
# Processing Record 2 of Set 11 | acarau
# Processing Record 3 of Set 11 | parauna
# Processing Record 4 of Set 11 | hilo
# Processing Record 5 of Set 11 | sao jose da coroa grande
# Processing Record 6 of Set 11 | khalkhal
# Processing Record 7 of Set 11 | aljezur
# Processing Record 8 of Set 11 | laiwu
# Processing Record 9 of Set 11 | santa marta
# Processing Record 10 of Set 11 | ketchikan
# Processing Record 11 of Set 11 | vityazevo
# Processing Record 12 of Set 11 | novo aripuana
# Processing Record 13 of Set 11 | port alfred
# Processing Record 14 of Set 11 | bandar abbas
# Processing Record 15 of Set 11 | kirakira
# Processing Record 16 of Set 11 | shchyolkino
# Processing Record 17 of Set 11 | oltinko'l
# Processing Record 18 of Set 11 | touba
# Processing Record 19 of Set 11 | richards bay
# Processing Record 20 of Set 11 | regeneracao
# Processing Record 21 of Set 11 | sangin
# Processing Record 22 of Set 11 | san luis de la loma
# Processing Record 23 of Set 11 | sangmelima
# Processing Record 24 of Set 11 | sao gabriel da cachoeira
# Processing Record 25 of Set 11 | sal rei
# Processing Record 26 of Set 11 | pionerskiy
# Processing Record 27 of Set 11 | malvik
# Processing Record 28 of Set 11 | hailar
# Processing Record 29 of Set 11 | el sauzal de rodriguez
# Processing Record 30 of Set 11 | iquique
# Processing Record 31 of Set 11 | chaozhou
# Processing Record 32 of Set 11 | tindouf
# Processing Record 33 of Set 11 | nemuro
# Processing Record 34 of Set 11 | suva
# Processing Record 35 of Set 11 | vimperk
# Processing Record 36 of Set 11 | anahuac
# Processing Record 37 of Set 11 | kolonia town
# Processing Record 38 of Set 11 | cam ranh
# Processing Record 39 of Set 11 | vicente guerrero
# Processing Record 40 of Set 11 | kasulu
# Processing Record 41 of Set 11 | dwarka
# Processing Record 42 of Set 11 | el negrito
# Processing Record 43 of Set 11 | laminusa
# Processing Record 44 of Set 11 | woolgoolga
# Processing Record 45 of Set 11 | hammerfest
# Processing Record 46 of Set 11 | kuraymah
# Processing Record 47 of Set 11 | kargopol'
# Processing Record 48 of Set 11 | norman
# Processing Record 49 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 0 of Set 12 | punta cana
# Processing Record 1 of Set 12 | uturoa
# Processing Record 2 of Set 12 | laguna
# Processing Record 3 of Set 12 | shindand
# Processing Record 4 of Set 12 | pitanga
# Processing Record 5 of Set 12 | trairi
# Processing Record 6 of Set 12 | ganghwa-gun
# Processing Record 7 of Set 12 | mirnyy
# Processing Record 8 of Set 12 | mrakovo
# Processing Record 9 of Set 12 | broken hill
# Processing Record 10 of Set 12 | song cau
# Processing Record 11 of Set 12 | sumberpucung
# Processing Record 12 of Set 12 | maryville
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | port macquarie
# Processing Record 15 of Set 12 | akrehamn
# Processing Record 16 of Set 12 | pindushi
# Processing Record 17 of Set 12 | topolobampo
# Processing Record 18 of Set 12 | tarko-sale
# Processing Record 19 of Set 12 | ciudad lazaro cardenas
# Processing Record 20 of Set 12 | nguigmi
# Processing Record 21 of Set 12 | porbandar
# Processing Record 22 of Set 12 | borogontsy
# Processing Record 23 of Set 12 | mantyharju
# Processing Record 24 of Set 12 | daru
# Processing Record 25 of Set 12 | haiku-pauwela
# Processing Record 26 of Set 12 | khandyga
# Processing Record 27 of Set 12 | mo i rana
# Processing Record 28 of Set 12 | mozhaysk
# Processing Record 29 of Set 12 | bayganin
# Processing Record 30 of Set 12 | vale de cambra
# Processing Record 31 of Set 12 | revda
# Processing Record 32 of Set 12 | sona
# Processing Record 33 of Set 12 | tortoli
# Processing Record 34 of Set 12 | abepura
# Processing Record 35 of Set 12 | tonghae
# Processing Record 36 of Set 12 | thinadhoo
# Processing Record 37 of Set 12 | mto wa mbu
# Processing Record 38 of Set 12 | pochep
# Processing Record 39 of Set 12 | bull savanna
# Processing Record 40 of Set 12 | ripley
# Processing Record 41 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 42 of Set 12 | springs
# Processing Record 43 of Set 12 | mong cai
# City not found. Skipping...
# Processing Record 44 of Set 12 | chui
# Processing Record 45 of Set 12 | gifford
# Processing Record 46 of Set 12 | torbat-e jam
# Processing Record 47 of Set 12 | las khorey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df =pd.DataFrame(city_data)

# Show Record Count

city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           necochea -38.5473 -58.7368    283.54        92           8
# 1              guane  22.2025 -84.0875    294.65        93           2
# 2  port-aux-francais -49.3500  70.2167    278.87        80          13
# 3         bredasdorp -34.5322  20.0403    292.08        52          87
# 4        olonkinbyen  70.9221  -8.7187    270.53        62          84
#
#    Wind Speed Country        Date
# 0        3.50      AR  1734417476
# 1        2.04      CU  1734417477
# 2       15.40      TF  1734417480
# 3        4.43      ZA  1734417481
# 4        4.44      SJ  1734417482

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 necochea -38.5473 -58.7368    283.54        92           8
# 1                    guane  22.2025 -84.0875    294.65        93           2
# 2        port-aux-francais -49.3500  70.2167    278.87        80          13
# 3               bredasdorp -34.5322  20.0403    292.08        52          87
# 4              olonkinbyen  70.9221  -8.7187    270.53        62          84
#
#          Wind Speed Country        Date
# City_ID
# 0              3.50      AR  1734417476
# 1              2.04      CU  1734417477
# 2             15.40      TF  1734417480
# 3              4.43      ZA  1734417481
# 4              4.44      SJ  1734417482

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Tempurature (C)')
plt.title('City Max Latitude vs. Tempurature (2024)')
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('City Latitude vs. Humidity (2024)')
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])

# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title('City Latitude vs. Cloudiness (2024)')
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2024)')
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
from scipy import stats


def calc_lin_req(lat,yvar):
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat,yvar)
    regress_values = lat * slope + intercept
    return regress_values,slope,intercept,rvalue

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                guane  22.2025  -84.0875    294.65        93           2
# 4          olonkinbyen  70.9221   -8.7187    270.53        62          84
# 6             thompson  55.7435  -97.8558    256.24        85         100
# 7              magadan  59.5667  150.8000    259.62        73         100
# 8        labrador city  52.9463  -66.9114    268.10        82         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.04      CU  1734417477
# 4              4.44      SJ  1734417482
# 6              2.06      CA  1734417484
# 7              5.06      RU  1734417486
# 8              7.60      CA  1734417487

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                           necochea -38.5473 -58.7368    283.54        92
# 2                  port-aux-francais -49.3500  70.2167    278.87        80
# 3                         bredasdorp -34.5322  20.0403    292.08        52
# 5        edinburgh of the seven seas -37.0676 -12.3116    289.19        91
# 9                         vila velha -20.3297 -40.2925    296.45        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 8        3.50      AR  1734417476
# 2                13       15.40      TF  1734417480
# 3                87        4.43      ZA  1734417481
# 5               100        8.95      SH  1734417483
# 9                75        5.66      BR  1734417488

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'],)

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Tempurature (C)')
plt.title('Latitude vs. Tempurature (2024)')

north_temp,slope,intercept,rvalue = calc_lin_req(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))

plt.plot(northern_hemi_df['Lat'],north_temp,color='red')
plt.annotate(line_eq,(50,255),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.8917391053426531

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Tempurature (C)')
plt.title('Latitude vs. Max Temp (2024)')

south_temp,slope,intercept,rvalue = calc_lin_req(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
plt.plot(southern_hemi_df['Lat'],south_temp,color='red')


line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(-20,285),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.5790034708812059

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity (2024)')

north_humid,slope,intercept,rvalue = calc_lin_req(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])

plt.plot(northern_hemi_df['Lat'],north_humid,color='red')

line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(50,60),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.3387473798493008

# %%
# Southern Hemisphere
# YOUR CODE HERE
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity (2024)')

south_humid,slope,intercept,rvalue = calc_lin_req(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])

plt.plot(southern_hemi_df['Lat'],south_humid,color='red')

line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(-40,50),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.2291071426855804

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness (2024)')



north_cloud,slope,intercept,rvalue = calc_lin_req(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])

plt.plot(northern_hemi_df['Lat'],north_humid,color='red')

line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(60,60),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.2487272994418894

# %%
# Southern Hemisphere
# YOUR CODE HERE
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness (2024)')


south_cloud,slope,intercept,rvalue = calc_lin_req(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])

plt.plot(southern_hemi_df['Lat'],south_humid,color='red')

line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(-30,20),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.3312508505449067

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed (2024)')


north_wind,slope,intercept,rvalue = calc_lin_req(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])

plt.plot(northern_hemi_df['Lat'],north_wind,color='red')

line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(50,2),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.05960515983423886

# %%
# Southern Hemisphere
# YOUR CODE HERE
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])

plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed (2024)')


south_wind,slope,intercept,rvalue = calc_lin_req(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])

plt.plot(southern_hemi_df['Lat'],south_wind,color='red')

line_eq = "y = "+ str(round(slope,2)) + "* x +" + str(round(intercept,2))
plt.annotate(line_eq,(-50,10),color='red')
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.15320502682126372

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
